# %%
import numpy as np
import pandas as pd
from GHSOM import GHSOM
from help_functions import *
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("../data/iris.csv")
y = df['Iris-setosa'].to_numpy()
X = df.drop(['Iris-setosa'], axis=1)

# Normalize dataset
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
ghsom_deep = GHSOM(
    input_dim=4,
    t1=0.07,
    t2=0.0035,
    training_epoch_num=30)

# %%
ghsom_deep.train(X, y)
# Out:
# Layer 0 Initialized, Global stopping criterion (tau2 * (qe0 or mqe0)): 0.2517
#    -> Spawning child 1_0-1 Num of samples: 48, Error: 10.51 > 0.25)
#    -> Spawning child 1_1-0 Num of samples: 17, Error: 3.98 > 0.25)
#    -> Spawning child 1_2-0 Num of samples: 16, Error: 3.26 > 0.25)
#    -> Spawning child 1_2-1 Num of samples: 20, Error: 2.94 > 0.25)
#    -> Spawning child 1_3-0 Num of samples: 15, Error: 3.15 > 0.25)
#    -> Spawning child 1_3-1 Num of samples: 32, Error: 8.48 > 0.25)
#    -> Spawning child 1_0-1_0-0 Num of samples: 18, Error: 1.96 > 0.25)
#    -> Spawning child 1_0-1_1-0 Num of samples: 7, Error: 0.61 > 0.25)
#    -> Spawning child 1_0-1_1-1 Num of samples: 5, Error: 0.38 > 0.25)
#    -> Spawning child 1_0-1_2-1 Num of samples: 5, Error: 0.48 > 0.25)
#    -> Spawning child 1_0-1_3-1 Num of samples: 9, Error: 1.23 > 0.25)
#    -> Spawning child 1_1-0_1-0 Num of samples: 4, Error: 0.41 > 0.25)
#    -> Spawning child 1_1-0_1-3 Num of samples: 5, Error: 0.42 > 0.25)
#    -> Spawning child 1_2-0_0-0 Num of samples: 4, Error: 0.43 > 0.25)
#    -> Spawning child 1_2-1_0-4 Num of samples: 5, Error: 0.39 > 0.25)
#    -> Spawning child 1_3-0_2-0 Num of samples: 4, Error: 0.32 > 0.25)
#    -> Spawning child 1_3-1_0-0 Num of samples: 4, Error: 0.60 > 0.25)
#    -> Spawning child 1_3-1_0-1 Num of samples: 4, Error: 0.46 > 0.25)
#    -> Spawning child 1_3-1_0-3 Num of samples: 4, Error: 0.36 > 0.25)
#    -> Spawning child 1_3-1_1-3 Num of samples: 4, Error: 0.37 > 0.25)
#    -> Spawning child 1_0-1_0-0_0-1 Num of samples: 8, Error: 0.34 > 0.25)
# Training finished!
# GHSOM results: Number of neurons: 175, QE: 0.059105220228242855, TE: 0.00516795865633075, Purity: 0.9731543624161074

# %%
plot_ghsom(ghsom_deep, X, y)
